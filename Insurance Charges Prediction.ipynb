# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('insurance.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.shape
# Out:
# (1338, 7)

# %%
#value counts for categorical data
print(data.sex.value_counts(),'\n',data.children.value_counts(),'\n',data.region.value_counts(),'\n',data.smoker.value_counts(),'\n')
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
#  0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#  southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64
#  no     1064
# yes     274
# Name: smoker, dtype: int64

# %% [markdown]
# # convert the categorical variable with numerical variables

# %%
data['sex']=data['sex'].map({'male':1 ,'female':0})
data['smoker']=data['smoker'].map({'yes':1 ,'no':0})
data['region']=data['region'].map({'southeast':1 ,'southwest':0,'northwest':2,'northeast':3})

# %%
data.head(10)
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       0  16884.92400
# 1   18    1  33.770         1       0       1   1725.55230
# 2   28    1  33.000         3       0       1   4449.46200
# 3   33    1  22.705         0       0       2  21984.47061
# 4   32    1  28.880         0       0       2   3866.85520
# 5   31    0  25.740         0       0       1   3756.62160
# 6   46    0  33.440         1       0       1   8240.58960
# 7   37    0  27.740         3       0       2   7281.50560
# 8   37    1  29.830         2       0       3   6406.41070
# 9   60    0  25.840         0       0       2  28923.13692

# %% [markdown]
# # EDA

# %%
#age distribution checking

plt.figure(figsize=(13,7))
sns.histplot(data.age,bins=20,kde=False,color='yellow')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency of each age')
plt.show()

# %%
#sex distribution checking

plt.figure(figsize=(13,7)) 
sns.countplot(x='sex',data= data)
plt.title('gender distribution')
# Out:
# Text(0.5, 1.0, 'gender distribution')

# %% [markdown]
# ***max number of people in dataset have a age below 20***

# %% [markdown]
#  ***from the graph , we notice that male and female are similar in number***

# %%
#bmi distribution checking
plt.figure(figsize=(13,7))
sns.histplot(data.bmi,bins=20,kde=True,color='green')
plt.title('bmi Distribution')
plt.xlabel('bmi')
plt.ylabel('Frequency of each bmi')
plt.show()

# %% [markdown]
# ***data is normal distribution,***
# ***The majority of people have Bmi in between 25 and 40 ,which is considered as overweight and could be a major factor in increasing the medical cost***

# %%
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.484305  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       1.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %% [markdown]
# # single column or variable ko anaylse krte h vo h univariate  analysis

# %%
plt.figure(figsize=(13,7)) 
sns.countplot(x='children',data= data)
plt.title('children distribution')
# Out:
# Text(0.5, 1.0, 'children distribution')

# %%
plt.figure(figsize=(13,7)) 
sns.countplot(x='smoker',data= data)
plt.title('smoker distribution')
# Out:
# Text(0.5, 1.0, 'smoker distribution')

# %% [markdown]
# ### checking Charges Distribution
# plt.figure(figsize=(13,7))
# sns.histplot(data.charges,bins=20,kde=True,color='blue')
# plt.title('charges Distribution')
# plt.xlabel('charges')
# plt.ylabel('Frequency of each charges')
# plt.show()

# %% [markdown]
# ***majority of charges are from 2000-13000, graph is positive skwed ,minimum charges are 30,000-50,000 and the most negligible are from 50,000 to 60,000***

# %% [markdown]
# ***majority of the medical expenses are below 20000,with the negligible number of patients having a medical expenses above 50000***

# %%
#realtuon between gender and smoker

#Relation between Gender and Smoker
plt.figure(figsize=(13,7))
sns.catplot(x='smoker',kind='count',hue='sex',data=data)
plt.xlabel('smoker')
plt.ylabel('count')
plt.title('Relation between Gender and Smoekr')
plt.show()

# %% [markdown]
# ***we can observe male smokers are more in numbers ,so i will assume that medical treatment expenses for male more than future***

# %%
plt.figure(figsize=(13,7))
plt.title('box plot for charges of women')
sns.boxplot(y='smoker',x='charges',data=data[(data.sex==0)],orient='h')
# Out:
# <Axes: title={'center': 'box plot for charges of women'}, xlabel='charges', ylabel='smoker'>

# %%
plt.figure(figsize=(13,7))
plt.title('box plot for charges of men')
sns.boxplot(y='smoker',x='charges',data=data[(data.sex==1)],orient='h')
# Out:
# <Axes: title={'center': 'box plot for charges of men'}, xlabel='charges', ylabel='smoker'>

# %% [markdown]
# ***the assumpution we assume,the medical expenses of males is greater than that of females in addition to that medical expenses of smokers is greater than that of non-smokers***

# %%
cor = data.corr()
cor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019 -0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185 -0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750 -0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673 -0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000  0.002181  0.787251
# region   -0.002127 -0.004588 -0.157566 -0.016569  0.002181  1.000000  0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251  0.006208  1.000000

# %%
plt.figure(figsize=(13, 7))
sns.heatmap(cor, annot = True, cmap = 'PiYG')
# Out:
# <Axes: >

# %% [markdown]
# ***by observing the above plot we can say that smokers have more expenses followed by age and bmi whereas region,gender,qnd children has no impact***

# %%
plt.figure(figsize=(13,7))
sns.catplot(x='smoker',y='age',kind='swarm',data=data)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#plt.figure(figsize=(13,7))
sns.scatterplot(x='age',y='charges',data=data[(data.smoker==0)])#non smoker==0
plt.title('scatter plot for charges of non smoker ')
plt.xlabel('Age')
plt.ylabel('Medical expenditure')  
plt.show()

# %% [markdown]
# ***majority of the points shows that medical expenses increas with the age which may be due to the fact that older people are ore prone to ilness .
# but there are some outliers which shows other illnessor expenses which may lead to increase in edical expenses***

# %%
sns.scatterplot(x='age',y='charges',data=data[(data.smoker==1)])
plt.title('scatter plot for charges of non smoker ')
plt.xlabel('Age')
plt.ylabel('Medical expenditure')
plt.show()

# %% [markdown]
# ***in this graph there are two segments ,one with high medical expenses which may  due to smoking related illness and other with low medical expenses which may due to age realted illness
# now in order to get more clearwe can combine both the graphs***

# %%
#multi varied analysis
#age distribution 
plt.figure(figsize=(15,5))
sns.lmplot(x='age',y='charges',data=data,hue='smoker')
plt.xlabel('age')
plt.ylabel('medical expenses')
plt.show()

# %% [markdown]
# ***now,we can clearly understand the variations in charges with respect to age and smoking habits.The expenses of smoker is higher than that of non-smokers irrespective of age.the non-smokers ,the cost of treatment increases with the age which is obvious***

# %%
#realtion betwwen bmi and medical expenses
plt.figure(figsize=(14,8))
sns.distplot(data[data.bmi>30]['charges'])
plt.title("charges for obese peeps ")
plt.xlabel("medical expenses")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8332\2191497372.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data.bmi>30]['charges'])

# %%
plt.figure(figsize=(14,8))
sns.distplot(data[data.bmi<30]['charges'])
plt.title("charges for obese peeps ")
plt.xlabel("medical expenses")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8332\1540910959.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data.bmi<30]['charges'])

# %% [markdown]
# ***people with bmi less than 30 are spending less where people with Bmi more than 30 are spending more***

# %% [markdown]
# # model building and evaluation

# %% [markdown]
# # linear regression

# %%
x=data.drop('charges',axis=1)
y=data.charges

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1003, 6), (335, 6), (1003,), (335,))

# %%
#linear regression
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# making prediction
y_pred=reg.predict(x_test)

# %%
# model evaluation
from sklearn import metrics
print('MAE',metrics.mean_absolute_error(y_test,y_pred))
print('RMSE',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print('R2 Score',metrics.r2_score(y_test,y_pred))
# Out:
# MAE 4201.136218008059
# RMSE 6146.1647117343855
# R2 Score 0.7497081429580856

# %% [markdown]
# # polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=2)
poly_reg
# Out:
# PolynomialFeatures()

# %%
#Transforming the feature to higher degree
x_train_poly=poly_reg.fit_transform(x_train)

#spitting data 
x_train,x_test,y_train,y_test=train_test_split(x_train_poly,y_train,test_size=0.2,random_state=42)

# %%
# train model
plr=LinearRegression()
plr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_plr=plr.predict(x_test)

# %%
#model evaluation
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred_plr))
print('RMSE',np.sqrt(metrics.mean_squared_error(y_test,y_pred_plr)))
print('R2 Score',metrics.r2_score(y_test,y_pred_plr))
# Out:
# MAE: 2939.3860688059704
# RMSE 4920.31468931517
# R2 Score 0.794289349232046

# %% [markdown]
# ***my model is able to explain 80% ofthe total data set***

# %% [markdown]
# # Making predcition sysrem

# %%
#input
age=21
sex=1
bmi=27
children=0
smoker=1
region = 1

# %%
charge=reg.predict([[age,sex,bmi,children,smoker, region]])
print('the charges of this new patient is $',charge[0])
# Out:
# the charges of this new patient is $ 25534.075284555787
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
